# %% [markdown]
# <a href="https://colab.research.google.com/github/RedSlashx/Entrenador-Adaptado-Phi414b/blob/main/nb/Phi_4_(14B)-GRPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# **Read our [blog post](https://unsloth.ai/blog/r1-reasoning) for guidance on how to train reasoning models.**
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
# Skip restarting message in Colab
import sys; modules = list(sys.modules.keys())
for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None

# !pip install unsloth vllm
# !pip install --upgrade pillow

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Use `PatchFastRL` before all functions to patch GRPO and other RL algorithms!

# %%
from unsloth import FastLanguageModel, PatchFastRL
PatchFastRL("GRPO", FastLanguageModel)
# Out:
# Unsloth: Patching Xformers to fix some performance issues.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %% [markdown]
# Load up `Phi-4 14B`, and set parameters

# %%
from unsloth import is_bfloat16_supported
import torch
max_seq_length = 512 # Can increase for longer reasoning traces
lora_rank = 16 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Phi-4",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.7, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["gate_proj", "up_proj", "down_proj",],
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
# Out:
# INFO 02-20 21:02:27 __init__.py:207] Automatically detected platform cuda.
# Unsloth: Switching from Unsloth dynamic quant to normal quant since
# we do not yet support fast inference for unsloth/phi-4-unsloth-bnb-4bit
# ==((====))==  Unsloth 2025.2.15: Fast Llama patching. Transformers: 4.48.3.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Unsloth: vLLM loading unsloth/phi-4-bnb-4bit with actual GPU utilization = 69.52%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 512. Num Sequences = 128.
# Unsloth: vLLM's KV Cache can use up to 0.28 GB. Also swap space = 2 GB.
# WARNING 02-20 21:02:31 config.py:2448] Casting torch.bfloat16 to torch.float16.
# INFO 02-20 21:02:45 config.py:549] This model supports multiple tasks: {'embed', 'reward', 'classify', 'score', 'generate'}. Defaulting to 'generate'.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'float16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection'], 'llm_int8_threshold': 6.0}
# INFO 02-20 21:02:45 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.3) with config: model='unsloth/phi-4-bnb-4bit', speculative_config=None, tokenizer='unsloth/phi-4-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=512, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/phi-4-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":128}, use_cached_outputs=False,
# tokenizer_config.json:   0%|          | 0.00/18.0k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.61M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/917k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.15M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/170 [00:00<?, ?B/s]
# INFO 02-20 21:02:49 cuda.py:178] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 02-20 21:02:49 cuda.py:226] Using XFormers backend.
# INFO 02-20 21:02:49 model_runner.py:1110] Starting to load model unsloth/phi-4-bnb-4bit...
# INFO 02-20 21:02:50 loader.py:1089] Loading weights with BitsAndBytes quantization.  May take a while ...
# INFO 02-20 21:02:50 weight_utils.py:254] Using model weights format ['*.safetensors']
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.11G [00:00<?, ?B/s]
# INFO 02-20 21:04:33 weight_utils.py:270] Time spent downloading weights for unsloth/phi-4-bnb-4bit: 102.864334 seconds
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 02-20 21:05:53 model_runner.py:1115] Loading model weights took 8.4920 GB
# INFO 02-20 21:05:53 punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 02-20 21:06:07 worker.py:267] Memory profiling takes 13.61 seconds
# INFO 02-20 21:06:07 worker.py:267] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.70) = 10.25GiB
# INFO 02-20 21:06:07 worker.py:267] model weights take 8.49GiB; non_torch_memory takes 0.05GiB; PyTorch activation peak memory takes 0.47GiB; the rest of the memory reserved for KV Cache is 1.24GiB.
# INFO 02-20 21:06:07 executor_base.py:111] # cuda blocks: 406, # CPU blocks: 655
# INFO 02-20 21:06:07 executor_base.py:116] Maximum concurrency for 512 tokens per request: 12.69x
# INFO 02-20 21:06:10 model_runner.py:1434] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 19/19 [00:41<00:00,  2.18s/it]
# INFO 02-20 21:06:51 model_runner.py:1562] Graph capturing finished in 42 secs, took 0.65 GiB
# INFO 02-20 21:06:51 llm_engine.py:436] init engine (profile, create kv cache, warmup model) took 58.48 seconds
# tokenizer_config.json:   0%|          | 0.00/18.0k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.61M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/917k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.15M [00:00<?, ?B/s]
# Not an error, but Unsloth cannot patch Attention layers with our manual autograd engine since either LoRA adapters
# are not enabled or a bias term (like in Qwen) is used.
# Not an error, but Unsloth cannot patch O projection layer with our manual autograd engine since either LoRA adapters
# are not enabled or a bias term (like in Qwen) is used.
# Unsloth 2025.2.15 patched 40 layers with 0 QKV layers, 0 O layers and 40 MLP layers.

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We directly leverage [@willccbb](https://gist.github.com/willccbb/4676755236bb08cab5f4e54a0475d6fb) for data prep and all reward functions. You are free to create your own!

# %%
import re
from datasets import load_dataset, Dataset

# Load and prep dataset
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

XML_COT_FORMAT = """\
<reasoning>
{reasoning}
</reasoning>
<answer>
{answer}
</answer>
"""

def extract_xml_answer(text: str) -> str:
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def extract_hash_answer(text: str) -> str | None:
    if "####" not in text:
        return None
    return text.split("####")[1].strip()

# Modified function to load and prep the custom dataset
def get_custom_questions(split="train") -> Dataset:
    # Cargamos el dataset "RedSlash/Quien-Domina-El-Mundo" desde Hugging Face
    data = load_dataset("RedSlash/Quien-Domina-El-Mundo", split=split)
    # Se asume que cada ejemplo posee una lista "conversations" donde:
    # - El primer mensaje (de "human") contiene la pregunta.
    # - El segundo mensaje (de "gpt") contiene la respuesta.
    data = data.map(lambda x: {
        'prompt': [
            {'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user', 'content': x['conversations'][0]['value']}
        ],
        'answer': x['conversations'][1]['value']
    })
    return data

dataset = get_custom_questions()

# Reward functions
def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_xml_answer(r) for r in responses]
    print('-'*20, f"Question:\n{q}",
          f"\nAnswer:\n{answer[0]}",
          f"\nResponse:\n{responses[0]}",
          f"\nExtracted:\n{extracted_responses[0]}")
    return [2.0 if r == a else 0.0 for r, a in zip(extracted_responses, answer)]

def int_reward_func(completions, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    extracted_responses = [extract_xml_answer(r) for r in responses]
    return [0.5 if r.isdigit() else 0.0 for r in extracted_responses]

def strict_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<reasoning>\n.*?\n</reasoning>\n<answer>\n.*?\n</answer>\n$"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def soft_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def count_xml(text) -> float:
    count = 0.0
    if text.count("<reasoning>\n") == 1:
        count += 0.125
    if text.count("\n</reasoning>\n") == 1:
        count += 0.125
    if text.count("\n<answer>\n") == 1:
        count += 0.125
        count -= len(text.split("\n</answer>\n")[-1]) * 0.001
    if text.count("\n</answer>") == 1:
        count += 0.125
        count -= (len(text.split("\n</answer>")[-1]) - 1) * 0.001
    return count

def xmlcount_reward_func(completions, **kwargs) -> list[float]:
    contents = [completion[0]["content"] for completion in completions]
    return [count_xml(c) for c in contents]
# Out:
# README.md:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# quien_domina.json:   0%|          | 0.00/1.49M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2844 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2844 [00:00<?, ? examples/s]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    use_vllm = True, # use vLLM for fast inference!
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    bf16 = is_bfloat16_supported(),
    fp16 = not is_bfloat16_supported(),
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 6, # Decrease if out of memory
    max_prompt_length = 256,
    max_completion_length = 200,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 100,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 6

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        xmlcount_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        int_reward_func,
        correctness_reward_func,
    ],
    args = training_args,
    train_dataset = dataset,
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 2,844 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 6 | Gradient Accumulation steps = 1
# \        /    Total batch size = 6 | Total steps = 100
#  "-____-"     Number of trainable parameters = 44,236,800
# -------------------- Question:
# **¿Qué posición defendió Roger Williams con tenacidad?**
# Answer:
# "Su crimen fundamental había sido esbozar una petición llamando al pueblo el originario de todo poder justo en la sociedad civil; ni el rey, ni siquiera Dios3. Esa era la posición que había defendido con tenacidad Roger Williams, fundador de la primera sociedad libre en lo que es ahora el estado de Rhode Island."
# Response:
# <reasoning>
# Roger Williams fue un clérigo y líder colonial estadounidense conocido por sus ideas progresistas que a menudo eran consideradas radicales en su época. Su postura más destacada y que abordaba con más tenacidad fue su defensa del principio de la separación de la Iglesia y el Estado. Williams sostenía que el gobierno civil no debería tener autoridad para regular la conciencia individual ni debería estar vinculado a una iglesia en particular. Esta creencia fue fundamental para su fundación de la Colonia de Rhode Island y Plantaciones de Providence en 1636, que se estableció con el principio de libertad religiosa.
#
# Además, Williams abogó por el reconocimiento de los derechos de propiedad de los pueblos nativos americanos, destacando sus convicciones sobre el trato justo y el respeto hacia las poblaciones originales. Su
# Extracted:
# <reasoning>
# Roger Williams fue un clérigo y líder colonial estadounidense conocido por sus ideas progresistas que a menudo eran consideradas radicales en su época. Su postura más destacada y que abordaba con más tenacidad fue su defensa del principio de la separación de la Iglesia y el Estado. Williams sostenía que el gobierno civil no debería tener autoridad para regular la conciencia individual ni debería estar vinculado a una iglesia en particular. Esta creencia fue fundamental para su fundación de la Colonia de Rhode Island y Plantaciones de Providence en 1636, que se estableció con el principio de libertad religiosa.
#
# Además, Williams abogó por el reconocimiento de los derechos de propiedad de los pueblos nativos americanos, destacando sus convicciones sobre el trato justo y el respeto hacia las poblaciones originales. Su
#     <div>
#
#       <progress value='44' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 44/100 1:05:51 < 1:27:48, 0.01 it/s, Epoch 0.02/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / xmlcount_reward_func</th>
#       <th>rewards / soft_format_reward_func</th>
#       <th>rewards / strict_format_reward_func</th>
#       <th>rewards / int_reward_func</th>
#       <th>rewards / correctness_reward_func</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.005667</td>
#       <td>0.292306</td>
#       <td>198.333344</td>
#       <td>0.000000</td>
#       <td>0.005667</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000005</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000005</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000007</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000006</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.145833</td>
#       <td>0.051031</td>
#       <td>200.000000</td>
#       <td>0.000005</td>
#       <td>0.145833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000005</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000006</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000007</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>-0.028833</td>
#       <td>0.376813</td>
#       <td>200.000000</td>
#       <td>0.000007</td>
#       <td>-0.028833</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000007</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000004</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000006</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000007</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000006</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000007</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000006</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000006</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000007</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000005</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>-0.141500</td>
#       <td>0.332640</td>
#       <td>188.333344</td>
#       <td>0.000013</td>
#       <td>-0.141500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000006</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000006</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000007</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>0.000007</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.000000</td>
#       <
# -------------------- Question:
# **¿Qué papel juegan los sistemas de defensa con misiles según el texto?**
# Answer:
# - "...cuyo propósito es establecer una primacía estratégica, inmune al contraataque."
# Response:
# <reasoning>
# Para determinar el papel que juegan los sistemas de defensa con misiles según el texto, es necesario identificar tal información especificada en el material proporcionado. Sin embargo, dado que el texto del documento no se ha proporcionado aquí, no puedo acceder directamente al texto para extraer detalles. En su lugar, asumiré un entendimiento general sobre los sistemas de defensa con misiles y cómo son descritos comúnmente en contextos estratégicos y de seguridad.
#
# Los sistemas de defensa con misiles suelen mencionarse en contextos relacionados con la defensa nacional y la seguridad internacional. Generalmente, se diseñan para proteger a un país de ataques con misiles balísticos. El papel clave que juegan estos sistemas incluye:
#
# 1. **Deterrentia:** Uno de los roles principales de los sistemas de defensa con misiles es actuar como una medida disuasoria.
# Extracted:
# <reasoning>
# Para determinar el papel que juegan los sistemas de defensa con misiles según el texto, es necesario identificar tal información especificada en el material proporcionado. Sin embargo, dado que el texto del documento no se ha proporcionado aquí, no puedo acceder directamente al texto para extraer detalles. En su lugar, asumiré un entendimiento general sobre los sistemas de defensa con misiles y cómo son descritos comúnmente en contextos estratégicos y de seguridad.
#
# Los sistemas de defensa con misiles suelen mencionarse en contextos relacionados con la defensa nacional y la seguridad internacional. Generalmente, se diseñan para proteger a un país de ataques con misiles balísticos. El papel clave que juegan estos sistemas incluye:
#
# 1. **Deterrentia:** Uno de los roles principales de los sistemas de defensa con misiles es actuar como una medida disuasoria.
# -------------------- Question:
# **¿Qué sucedió con los generales indonesios respecto a Timor Oriental?**
# Answer:
# "Los generales indonesios juraron que nunca abandonarían lo que el ministro de Exteriores australiano Gareth Evans llamó la provincia indonesia de Timor Oriental cuando estaba llegando a un acuerdo para robar el petróleo timorés. Mientras los generales gobernantes conservaron el apoyo de Estados Unidos, a lo largo de décadas de asesinatos casi genocidas, sus objetivos eran realistas."
# Response:
# <reasoning>
# La situación de los generales indonesios respecto a Timor Oriental se relaciona con los eventos que ocurrieron alrededor de 1975 y 1999, durante el proceso de independencia de Timor Oriental de Indonesia. En esta época, hubo una serie de eventos conflictivos y problemáticos relacionados con estas figuras militares.
#
# 1. **Contexto histórico:** Después de que Portugal dejara Timor Oriental en 1975, las tensiones crecieron en la región. El 28 de noviembre de 1975, Indonesia invadió Timor Oriental, alegando el derecho de proteger a los timorenses bajo el pretexto del "Comunismo Temprano". Esta invasión fue liderada por la élite militar indonesia.
#
# 2. **Operación Seroja:** Esta fue la operación militar que condujo a la invasión y posterior ocupación
# Extracted:
# <reasoning>
# La situación de los generales indonesios respecto a Timor Oriental se relaciona con los eventos que ocurrieron alrededor de 1975 y 1999, durante el proceso de independencia de Timor Oriental de Indonesia. En esta época, hubo una serie de eventos conflictivos y problemáticos relacionados con estas figuras militares.
#
# 1. **Contexto histórico:** Después de que Portugal dejara Timor Oriental en 1975, las tensiones crecieron en la región. El 28 de noviembre de 1975, Indonesia invadió Timor Oriental, alegando el derecho de proteger a los timorenses bajo el pretexto del "Comunismo Temprano". Esta invasión fue liderada por la élite militar indonesia.
#
# 2. **Operación Seroja:** Esta fue la operación militar que condujo a la invasión y posterior ocupación
# -------------------- Question:
# **¿Cuál era el principal objetivo de la conquista del resto de la India por parte del Reino Unido?**
# Answer:
# "La conquista del resto de la India fue, en gran medida, un intento de obtener el monopolio del comercio del opio para la colosal empresa de narcotráfico del Reino Unido."
# Response:
# <reasoning>
# Para comprender el principal objetivo de la conquista del resto de la India por parte del Reino Unido, es fundamental considerar tanto las motivaciones económicas como estratégicas de la época.
#
# 1. **Intereses Económicos**:
#    - La India era rica en recursos y materiales críticos que eran altamente valorados en el Reino Unido e Inglaterra. Esto incluía textiles, especias, y más tarde, el yute, la seda y el algodón. Los productos de las colonias indias se exportaban a Gran Bretaña, alimentando tanto la economía local como la nacional.
#    - El control del comercio indio permitió a los británicos beneficiarse enormemente debido a la imposición de monopolios en varias industrias clave, como la Compañía Británica de las Indias Orientales, que jugó un papel crucial en
# Extracted:
# <reasoning>
# Para comprender el principal objetivo de la conquista del resto de la India por parte del Reino Unido, es fundamental considerar tanto las motivaciones económicas como estratégicas de la época.
#
# 1. **Intereses Económicos**:
#    - La India era rica en recursos y materiales críticos que eran altamente valorados en el Reino Unido e Inglaterra. Esto incluía textiles, especias, y más tarde, el yute, la seda y el algodón. Los productos de las colonias indias se exportaban a Gran Bretaña, alimentando tanto la economía local como la nacional.
#    - El control del comercio indio permitió a los británicos beneficiarse enormemente debido a la imposición de monopolios en varias industrias clave, como la Compañía Británica de las Indias Orientales, que jugó un papel crucial en
# -------------------- Question:
# **¿Cuál es la cuestión fundamental de las relaciones internacionales según el texto?**
# Answer:
# "La cuestión fundamental de las relaciones internacionales, pues, es si Estados Unidos debería aceptar que otras grandes potencias tengan influencia en sus regiones respectivas."
# Response:
# <reasoning>
# Para determinar la cuestión fundamental de las relaciones internacionales según el texto, primero necesitamos identificar el enfoque central o tema predominante del texto. Las relaciones internacionales generalmente tratan temas como el poder estatal, la cooperación internacional, el comercio, la seguridad global, los derechos humanos, las organizaciones internacionales, las guerras y las alianzas, entre otros.
#
# Sin embargo, dado que no se proporcionó un texto específico aquí, puedo señalar que muchas obras fundamentales en relaciones internacionales destacan cuestiones como el equilibrio de poder, la seguridad nacional y los acuerdos diplomáticos. Las escuelas de pensamiento como el realismo, el liberalismo y el constructivismo también ofrecen puntos de vista diferentes sobre la cuestión fundamental.
#
# - **Realismo**: Se centra en el equilibrio de poder y la autosuficiencia de los estados
# Extracted:
# <reasoning>
# Para determinar la cuestión fundamental de las relaciones internacionales según el texto, primero necesitamos identificar el enfoque central o tema predominante del texto. Las relaciones internacionales generalmente tratan temas como el poder estatal, la cooperación internacional, el comercio, la seguridad global, los derechos humanos, las organizaciones internacionales, las guerras y las alianzas, entre otros.
#
# Sin embargo, dado que no se proporcionó un texto específico aquí, puedo señalar que muchas obras fundamentales en relaciones internacionales destacan cuestiones como el equilibrio de poder, la seguridad nacional y los acuerdos diplomáticos. Las escuelas de pensamiento como el realismo, el liberalismo y el constructivismo también ofrecen puntos de vista diferentes sobre la cuestión fundamental.
#
# - **Realismo**: Se centra en el equilibrio de poder y la autosuficiencia de los estados
# -------------------- Question:
# **¿Cómo describe el texto el sabotaje continuado por parte de Washington hacia los intentos de establecer una zona libre de armas nucleares?**
# Answer:
# "Hay mucho más en juego en el continuado sabotaje de Washington a esos intentos con el fin de proteger a su aliado israelí."
# Response:
# <reasoning>
# To determine how the text describes the saboteur role of Washington in thwarting efforts to establish a nuclear-free zone, we need to identify and analyze specific language or phrases used to detail Washington's actions or stance, as described in the text.
#
# 1. **Identify Key Phrases**: Look for terms commonly associated with obstruction such as "obstruct", "prevent", "hinder", "block", "resist", "oppose", or any words indicating delay or interference.
#
# 2. **Examine the Context**: Assess how Washington's actions are framed—are they portrayed as diplomatic moves, coercive actions, political pressure, or something else? This will give insight into the characterization of their involvement.
#
# 3. **Analyze Intent and Consequences**: Consider the text's portrayal of Washington's intentions—are they depicted as self-interested, defensive, or possibly in reaction to external pressures? Additionally, evaluate the implied or stated consequences of their actions on the nuclear-free zone initiative
# Extracted:
# <reasoning>
# To determine how the text describes the saboteur role of Washington in thwarting efforts to establish a nuclear-free zone, we need to identify and analyze specific language or phrases used to detail Washington's actions or stance, as described in the text.
#
# 1. **Identify Key Phrases**: Look for terms commonly associated with obstruction such as "obstruct", "prevent", "hinder", "block", "resist", "oppose", or any words indicating delay or interference.
#
# 2. **Examine the Context**: Assess how Washington's actions are framed—are they portrayed as diplomatic moves, coercive actions, political pressure, or something else? This will give insight into the characterization of their involvement.
#
# 3. **Analyze Intent and Consequences**: Consider the text's portrayal of Washington's intentions—are they depicted as self-interested, defensive, or possibly in reaction to external pressures? Additionally, evaluate the implied or stated consequences of their actions on the nuclear-free zone initiative
# -------------------- Question:
# **¿Cuál fue el papel del ejército financiado por Estados Unidos en Colombia según el texto?**
# Answer:
# "que a menudo actuaron en estrecha colaboración con el ejército financiado por Estados Unidos."
# Response:
# <reasoning>
# Para responder a esta pregunta, necesito analizar el contexto y el contenido del texto para identificar cualquier referencia específica sobre el papel del ejército financiado por Estados Unidos en Colombia. Es importante determinar si el texto describe actividades, misiones o colaboraciones específicas del ejército que reciben apoyo financiero de Estados Unidos. Esto podría incluir esfuerzos de combate al narcotráfico, entrenamiento militar o operaciones antiterroristas. Sin el texto específico, no puedo referenciar detalles directos, pero procederé basándome en un escenario general relacionado con la cooperación histórica entre Estados Unidos y Colombia.
#
# Históricamente, la financiación de Estados Unidos al ejército colombiano, especialmente a través de iniciativas como la Operación Libertad Duradera–Colombia, ha sido principalmente para combatir el narcotráfico y fortalecer las fuer
# Extracted:
# <reasoning>
# Para responder a esta pregunta, necesito analizar el contexto y el contenido del texto para identificar cualquier referencia específica sobre el papel del ejército financiado por Estados Unidos en Colombia. Es importante determinar si el texto describe actividades, misiones o colaboraciones específicas del ejército que reciben apoyo financiero de Estados Unidos. Esto podría incluir esfuerzos de combate al narcotráfico, entrenamiento militar o operaciones antiterroristas. Sin el texto específico, no puedo referenciar detalles directos, pero procederé basándome en un escenario general relacionado con la cooperación histórica entre Estados Unidos y Colombia.
#
# Históricamente, la financiación de Estados Unidos al ejército colombiano, especialmente a través de iniciativas como la Operación Libertad Duradera–Colombia, ha sido principalmente para combatir el narcotráfico y fortalecer las fuer
# -------------------- Question:
# ¿Cuál es el impacto del muro en la agricultura palestina según los informes de la ONU?
# Answer:
# "una disminución de más del 80 en el número de campesinos que cultivan sus tierras de manera habitual y un declive del 60 en la producción total de olivares, entre otros efectos dañinos"
# Response:
# <reasoning>
# Para determinar el impacto del muro en la agricultura palestina según los informes de la ONU, necesitamos considerar la información disponible publicada por entidades de la ONU como OCHA (Oficina de Coordinación de Asuntos Humanitarios) o la ONU-Hábitat. Estos informes a menudo discuten los desafíos humanitarios en la región de Palestina Occidental.
#
# A partir de los informes disponibles, el muro de la Paz, construido por Israel, ha impactado significativamente en la agricultura palestina al interrumpir el acceso a la tierra. Este impacto se extiende en varias dimensiones:
#
# 1. **Acceso a la Tierra**: El muro ha atrapado a tierras agrícolas palestinas en el lado israelí. Los agricultores palestinos que dependen de
# Extracted:
# <reasoning>
# Para determinar el impacto del muro en la agricultura palestina según los informes de la ONU, necesitamos considerar la información disponible publicada por entidades de la ONU como OCHA (Oficina de Coordinación de Asuntos Humanitarios) o la ONU-Hábitat. Estos informes a menudo discuten los desafíos humanitarios en la región de Palestina Occidental.
#
# A partir de los informes disponibles, el muro de la Paz, construido por Israel, ha impactado significativamente en la agricultura palestina al interrumpir el acceso a la tierra. Este impacto se extiende en varias dimensiones:
#
# 1. **Acceso a la Tierra**: El muro ha atrapado a tierras agrícolas palestinas en el lado israelí. Los agricultores palestinos que dependen de
# -------------------- Question:
# ¿Qué reveló el relato oral del general Burchinal sobre las operaciones CD?
# Answer:
# "Según él, la capitulación soviética nunca estuvo en duda. Las operaciones CD estaban concebidas para dejar muy claro a los soviéticos que apenas eran rivales en la confrontación militar y que podrían ser destruidos con facilidad."
# Response:
# <reasoning>
# El relato oral del general Burchinal sobre las Operaciones CD, una serie de experimentos médicos realizados durante la Segunda Guerra Mundial en la Estación de Radiología de Camp Detrick (ahora conocida como Fort Detrick) en Maryland, proporciona información sobre la naturaleza y los resultados de estos experimentos. Estas operaciones se llevaron a cabo entre finales de los años 40 y 1953 e involucraron la exposición de sujetos humanos, a menudo prisioneros de guerra y trabajadores del gobierno, a radiación ionizante como parte de estudios de bioseguridad destinados a explorar los efectos de la radiación en el cuerpo humano.
#
# El objetivo era determinar la dosis letal de radiación y desarrollar contramedidas para un posible ataque nuclear. Sin embargo, las críticas éticas y la falta de consentimiento informado de
# Extracted:
# <reasoning>
# El relato oral del general Burchinal sobre las Operaciones CD, una serie de experimentos médicos realizados durante la Segunda Guerra Mundial en la Estación de Radiología de Camp Detrick (ahora conocida como Fort Detrick) en Maryland, proporciona información sobre la naturaleza y los resultados de estos experimentos. Estas operaciones se llevaron a cabo entre finales de los años 40 y 1953 e involucraron la exposición de sujetos humanos, a menudo prisioneros de guerra y trabajadores del gobierno, a radiación ionizante como parte de estudios de bioseguridad destinados a explorar los efectos de la radiación en el cuerpo humano.
#
# El objetivo era determinar la dosis letal de radiación y desarrollar contramedidas para un posible ataque nuclear. Sin embargo, las críticas éticas y la falta de consentimiento informado de
# -------------------- Question:
# ¿Quién escribió sobre la posibilidad de que Estados Unidos vuelva a utilizar los tribunales militares en Guantánamo y dónde fue publicado?
# Answer:
# "25 Glaberson, William, U. S. May Revive Guantánamo Military Courts, The New York Times, 1-5-2009."
# Response:
# <reasoning>
# Para responder a esta pregunta, debemos identificar cualquier autor conocido que haya escrito específicamente sobre la posibilidad de que Estados Unidos vuelva a utilizar los tribunales militares en Guantánamo. Uno de los autores notables que ha abordado el tema de los tribunales militares en Estados Unidos es el profesor de derecho Jonathan Hafetz. Es conocido por su trabajo en derechos civiles y la revisión judicial de las acciones del poder ejecutivo, incluidas las políticas relacionadas con Guantánamo.
#
# En particular, un artículo relevante es "The New Military Tribunals: Constitutional and Statutory Challenges" de Jonathan Hafetz, publicado en la Harvard Law Review. En su trabajo, Hafetz discute la legalidad y la constitucionalidad de los tribunales militares, incluidos los establecidos después de los ataques del 11 de septiembre
# Extracted:
# <reasoning>
# Para responder a esta pregunta, debemos identificar cualquier autor conocido que haya escrito específicamente sobre la posibilidad de que Estados Unidos vuelva a utilizar los tribunales militares en Guantánamo. Uno de los autores notables que ha abordado el tema de los tribunales militares en Estados Unidos es el profesor de derecho Jonathan Hafetz. Es conocido por su trabajo en derechos civiles y la revisión judicial de las acciones del poder ejecutivo, incluidas las políticas relacionadas con Guantánamo.
#
# En particular, un artículo relevante es "The New Military Tribunals: Constitutional and Statutory Challenges" de Jonathan Hafetz, publicado en la Harvard Law Review. En su trabajo, Hafetz discute la legalidad y la constitucionalidad de los tribunales militares, incluidos los establecidos después de los ataques del 11 de septiembre
# -------------------- Question:
# ¿Qué indica el texto sobre las preferencias de sectores económicamente poderosos en Estados Unidos respecto a Cuba?
# Answer:
# "Lo interesante en este caso es el rechazo de sectores económicamente poderosos de Estados Unidos que también prefieren la normalización y que suelen ser muy influyentes en la política: compañías energéticas, agrarias, farmacéuticas y otras."
# Response:
# <reasoning>
# Para responder a la pregunta sobre lo que indica el texto sobre las preferencias de sectores económicamente poderosos en Estados Unidos respecto a Cuba, analizaremos cualquier indicación presente en el texto relacionada con estas preferencias.
#
# 1. **Contexto del texto**: Primero, necesitamos identificar si el texto proporciona información específica o directa sobre las preferencias de sectores económicamente poderosos en Estados Unidos con respecto a Cuba.
#
# 2. **Actores económicos**: Generalmente, las preferencias de sectores económicamente poderosos en Estados Unidos pueden incluir intereses empresariales, corporativos o de inversión que buscan oportunidades de mercado, relaciones comerciales y ventajas económicas.
#
# 3. **Influencia política**: Estos sectores pueden tener preferencias que influyan en la política exterior estadounidense, incluyendo el levantamiento de sanciones o ap
# Extracted:
# <reasoning>
# Para responder a la pregunta sobre lo que indica el texto sobre las preferencias de sectores económicamente poderosos en Estados Unidos respecto a Cuba, analizaremos cualquier indicación presente en el texto relacionada con estas preferencias.
#
# 1. **Contexto del texto**: Primero, necesitamos identificar si el texto proporciona información específica o directa sobre las preferencias de sectores económicamente poderosos en Estados Unidos con respecto a Cuba.
#
# 2. **Actores económicos**: Generalmente, las preferencias de sectores económicamente poderosos en Estados Unidos pueden incluir intereses empresariales, corporativos o de inversión que buscan oportunidades de mercado, relaciones comerciales y ventajas económicas.
#
# 3. **Influencia política**: Estos sectores pueden tener preferencias que influyan en la política exterior estadounidense, incluyendo el levantamiento de sanciones o ap
# -------------------- Question:
# **¿Quién escribió sobre el acuerdo entre Corea del Norte e Irán respecto a misiles en 1995?**
# Answer:
# "Oded Granot, Background on North Korea-Iran Missile Deal, Maariv, 14-4-1995."
# Response:
# <reasoning>
# To address this question, we need to identify the author of any written work discussing the agreement between North Korea and Iran regarding missiles in 1995. This would involve historical events between these two countries where they engaged in discussions or agreements about missile technology.
#
# During the 1990s, both North Korea and Iran were subjects of international scrutiny due to their missile programs. In the mid-1990s, there were reports and concerns about the collaboration between these two nations, particularly around their missile technology programs. One significant event that involved North Korea and Iran was reported in 1995 when military officials from both countries agreed to collaborate on missile technology.
#
# The report of this agreement and subsequent developments between North Korea and Iran was primarily documented by international media and intelligence agencies. Notably, a significant article was written by David E. Sanger of The New York Times in 1995. Sanger reported on a Defense Intelligence Agency assessment about an agreement between North Korea and Iran for an
# Extracted:
# <reasoning>
# To address this question, we need to identify the author of any written work discussing the agreement between North Korea and Iran regarding missiles in 1995. This would involve historical events between these two countries where they engaged in discussions or agreements about missile technology.
#
# During the 1990s, both North Korea and Iran were subjects of international scrutiny due to their missile programs. In the mid-1990s, there were reports and concerns about the collaboration between these two nations, particularly around their missile technology programs. One significant event that involved North Korea and Iran was reported in 1995 when military officials from both countries agreed to collaborate on missile technology.
#
# The report of this agreement and subsequent developments between North Korea and Iran was primarily documented by international media and intelligence agencies. Notably, a significant article was written by David E. Sanger of The New York Times in 1995. Sanger reported on a Defense Intelligence Agency assessment about an agreement between North Korea and Iran for an
# -------------------- Question:
# **¿Qué cambios económicos y políticos comenzaron en la década de 1970?**
# Answer:
# - "Se remontan a la década de 1970, cuando la economía política pasó por transformaciones fundamentales, lo que acabó con la comúnmente denominada edad dorada del capitalismo de Estado."
# Response:
# <reasoning>
# Para entender los cambios económicos y políticos que comenzaron en la década de 1970, es útil considerar varios aspectos globales y regionales. Durante esta década, múltiples factores influyeron en la trayectoria económica y política del mundo:
#
# 1. **Estanflación y crisis del petróleo**: La primera gran crisis del petróleo ocurrió en 1973, tras la Guerra del Yom Kippur, llevada a cabo por la Organización de Países Exportadores de Petróleo (OPEP). Los países árabes ámpliamente aumentaron los precios del petróleo y redujeron la producción, causando un aumento de precios global y desaceleración económica en un fenómeno conocido como estanflación. La segunda crisis del petróleo en 1979 fue impuesta debido a la Revolución Iraní.
#
#
# Extracted:
# <reasoning>
# Para entender los cambios económicos y políticos que comenzaron en la década de 1970, es útil considerar varios aspectos globales y regionales. Durante esta década, múltiples factores influyeron en la trayectoria económica y política del mundo:
#
# 1. **Estanflación y crisis del petróleo**: La primera gran crisis del petróleo ocurrió en 1973, tras la Guerra del Yom Kippur, llevada a cabo por la Organización de Países Exportadores de Petróleo (OPEP). Los países árabes ámpliamente aumentaron los precios del petróleo y redujeron la producción, causando un aumento de precios global y desaceleración económica en un fenómeno conocido como estanflación. La segunda crisis del petróleo en 1979 fue impuesta debido a la Revolución Iraní.
# -------------------- Question:
# **¿Cómo describió Richard Holbrooke el bombardeo a la RTS?**
# Answer:
# "El muy bien considerado diplomático Richard Holbrooke, entonces enviado especial a Yugoslavia, describió el exitoso bombardeo a la RTS como enormemente importante y, creo, un hecho positivo."
# Response:
# <reasoning>
# 1. Richard Holbrooke fue un diplomático estadounidense que desempeñó un papel importante en los acuerdos de paz que resultaron en la creación de Bosnia y Herzegovina.
#
# 2. Durante los conflictos de la guerra de Bosnia a finales de los años 90, la República Federal de Yugoslavia (que incluye las actuales Serbia y Montenegro) fue criticada por apoyar a los serbobosnios, más específicamente al General Ratko Mladić, el principal comandante de las fuerzas serbobosnias.
#
# 3. El 1 de mayo de 1999, Estados Unidos y sus aliados de la OTAN llevaron a cabo un bombardeo de la sede de la Radio y Televisión Serbia (RTS) en Belgrado como parte de la campaña contra las fuerzas serbias en Kosovo.
#
# 4. La justificación dada
# Extracted:
# <reasoning>
# 1. Richard Holbrooke fue un diplomático estadounidense que desempeñó un papel importante en los acuerdos de paz que resultaron en la creación de Bosnia y Herzegovina.
#
# 2. Durante los conflictos de la guerra de Bosnia a finales de los años 90, la República Federal de Yugoslavia (que incluye las actuales Serbia y Montenegro) fue criticada por apoyar a los serbobosnios, más específicamente al General Ratko Mladić, el principal comandante de las fuerzas serbobosnias.
#
# 3. El 1 de mayo de 1999, Estados Unidos y sus aliados de la OTAN llevaron a cabo un bombardeo de la sede de la Radio y Televisión Serbia (RTS) en Belgrado como parte de la campaña contra las fuerzas serbias en Kosovo.
#
# 4. La justificación dada
# -------------------- Question:
# ¿Cómo describe el texto la política imperial en diferentes partes del mundo?
# Answer:
# "No es raro que la política imperial siga una trayectoria similar en diferentes partes del mundo."
# Response:
# <reasoning>
# To address this question, we need to identify the specific text being referred to, as it is not provided here. However, we can approach this by considering common themes in texts that discuss imperial policies across different regions. Typically, such texts might explore how empires exerted control and influence over various parts of the world, often focusing on aspects like economic exploitation, cultural assimilation, political governance, and military dominance.
#
# 1. **Economic Policies**: Many empires implemented policies to exploit the natural and human resources of their colonies. This could involve forced labor, resource extraction, and the establishment of trade monopolies that benefitted the imperial power more than the colony.
#
# 2. **Cultural Policies**: Imperial powers often imposed their own culture, language, and education systems on their colonies. This cultural assimilation could lead to the erosion of indigenous cultures and languages.
#
# 3. **Political Policies**: Different regions experienced varied forms of governance. Some were directly ruled by imperial officials, while others
# Extracted:
# <reasoning>
# To address this question, we need to identify the specific text being referred to, as it is not provided here. However, we can approach this by considering common themes in texts that discuss imperial policies across different regions. Typically, such texts might explore how empires exerted control and influence over various parts of the world, often focusing on aspects like economic exploitation, cultural assimilation, political governance, and military dominance.
#
# 1. **Economic Policies**: Many empires implemented policies to exploit the natural and human resources of their colonies. This could involve forced labor, resource extraction, and the establishment of trade monopolies that benefitted the imperial power more than the colony.
#
# 2. **Cultural Policies**: Imperial powers often imposed their own culture, language, and education systems on their colonies. This cultural assimilation could lead to the erosion of indigenous cultures and languages.
#
# 3. **Political Policies**: Different regions experienced varied forms of governance. Some were directly ruled by imperial officials, while others
# -------------------- Question:
# **¿Cuál es el patrón regular descrito respecto al cumplimiento de los acuerdos de alto el fuego?**
# Answer:
# "El patrón regular ha sido que Israel no respeta el acuerdo en cuestión, mientras que Hamás lo respeta hasta que un brusco incremento de la violencia israelí suscita una respuesta suya, a la que le sigue una brutalidad israelí más virulenta todavía."
# Response:
# <reasoning>
# Para determinar el patrón regular descrito respecto al cumplimiento de los acuerdos de alto el fuego, primero debemos entender qué elementos se han observado consistentemente en estos acuerdos. Históricamente, los acuerdos de alto el fuego pueden verse influenciados por dinámicas como:
#
# 1. **Ciclos de Tregua y Hostilidades**: A menudo, después de un alto el fuego, las partes pueden experimentar una tregua inicial, seguida de un retorno a las hostilidades debido a violaciones de los términos del acuerdo o debido a conflictos subyacentes no resueltos.
#
# 2. **Violaciones por ambas partes**: Los acuerdos de alto el fuego son comúnmente violados, ya sea por un pequeño grupo o por una de las partes principales. Estas violaciones pueden ser intencionadas o el resultado de
# Extracted:
# <reasoning>
# Para determinar el patrón regular descrito respecto al cumplimiento de los acuerdos de alto el fuego, primero debemos entender qué elementos se han observado consistentemente en estos acuerdos. Históricamente, los acuerdos de alto el fuego pueden verse influenciados por dinámicas como:
#
# 1. **Ciclos de Tregua y Hostilidades**: A menudo, después de un alto el fuego, las partes pueden experimentar una tregua inicial, seguida de un retorno a las hostilidades debido a violaciones de los términos del acuerdo o debido a conflictos subyacentes no resueltos.
#
# 2. **Violaciones por ambas partes**: Los acuerdos de alto el fuego son comúnmente violados, ya sea por un pequeño grupo o por una de las partes principales. Estas violaciones pueden ser intencionadas o el resultado de
# -------------------- Question:
# **¿Qué tipo de ayuda material estaba proporcionando al Partido de los Trabajadores del Kurdistán (PKK) según el proyecto condenado?**
# Answer:
# "La ayuda material era un asesoramiento legal."
# Response:
# <reasoning>
# Para responder a esta pregunta necesitamos entender el contexto y el tipo de ayuda material que se podría proporcionar al Partido de los Trabajadores del Kurdistán (PKK). El PKK es una organización que ha sido clasificada como un grupo terrorista por varios países, incluyendo Turquía, Estados Unidos y la Unión Europea. Esto significa que cualquier tipo de apoyo o ayuda proporcionada al PKK podría ser considerado ilegal en muchos países.
#
# El tipo de "ayuda material" se refiere generalmente al apoyo que incluye suministros físicos o recursos que pueden ser utilizados directamente por organizaciones o individuos. En el caso de grupos armados o rebeldes, esto podría incluir armamento, municiones, comida, ropa, dinero u otras formas de apoyo logístico o financiero.
#
# Sin embargo, la pregunta específica hace referencia a un "proyecto con
# Extracted:
# <reasoning>
# Para responder a esta pregunta necesitamos entender el contexto y el tipo de ayuda material que se podría proporcionar al Partido de los Trabajadores del Kurdistán (PKK). El PKK es una organización que ha sido clasificada como un grupo terrorista por varios países, incluyendo Turquía, Estados Unidos y la Unión Europea. Esto significa que cualquier tipo de apoyo o ayuda proporcionada al PKK podría ser considerado ilegal en muchos países.
#
# El tipo de "ayuda material" se refiere generalmente al apoyo que incluye suministros físicos o recursos que pueden ser utilizados directamente por organizaciones o individuos. En el caso de grupos armados o rebeldes, esto podría incluir armamento, municiones, comida, ropa, dinero u otras formas de apoyo logístico o financiero.
#
# Sin embargo, la pregunta específica hace referencia a un "proyecto con
# -------------------- Question:
# **¿Cómo describió un diplomático occidental las acciones de Shimon Peres?**
# Answer:
# "Los crímenes de Peres en aquel caso alcanzaron nuevas cotas de brutalidad calculada y asesinato arbitrario, en palabras de un diplomático occidental conocedor de la región."
# Response:
# <reasoning>
# Para responder a esta pregunta, es importante entender el contexto y los eventos históricos durante los cuales Shimon Peres, una figura política prominente de Israel, estuvo activa. Shimon Peres desempeñó varios roles claves en el gobierno israelí, incluidos Primer Ministro y Ministro de Asuntos Exteriores, y fue una figura central en la política israelí durante varias décadas.
#
# Durante su carrera, Peres estuvo involucrado en negociaciones de paz y diplomacia, particularmente en el período posterior a la Guerra Fría. Es conocido por su participación en los Acuerdos de Oslo en la década de 1990, que intentaron establecer una paz entre Israel e Israel. Estos acuerdos fueron altamente controvertidos y recibieron tanto aplausos como críticas por parte de diferentes grupos y gobiernos.
#
# Un diplomático occ
# Extracted:
# <reasoning>
# Para responder a esta pregunta, es importante entender el contexto y los eventos históricos durante los cuales Shimon Peres, una figura política prominente de Israel, estuvo activa. Shimon Peres desempeñó varios roles claves en el gobierno israelí, incluidos Primer Ministro y Ministro de Asuntos Exteriores, y fue una figura central en la política israelí durante varias décadas.
#
# Durante su carrera, Peres estuvo involucrado en negociaciones de paz y diplomacia, particularmente en el período posterior a la Guerra Fría. Es conocido por su participación en los Acuerdos de Oslo en la década de 1990, que intentaron establecer una paz entre Israel e Israel. Estos acuerdos fueron altamente controvertidos y recibieron tanto aplausos como críticas por parte de diferentes grupos y gobiernos.
#
# Un diplomático occ
# -------------------- Question:
# ¿Cuál es la estrategia utilizada por las compañías energéticas en Estados Unidos para influir en la opinión pública sobre el calentamiento global?
# Answer:
# "Hay una inmensa campaña de relaciones públicas en Estados Unidos, organizada abiertamente por las compañías energéticas y el mundo empresarial, para tratar de convencer a la opinión pública de que el calentamiento global o bien es irreal o no es resultado de la actividad humana; y ha tenido cierto impacto."
# Response:
# <reasoning>
# Las compañías energéticas en Estados Unidos, especialmente aquellas que se beneficiarían de la explotación continua de combustibles fósiles, han empleado diversas estrategias a lo largo de los años para influir en la opinión pública sobre temas relacionados con el calentamiento global y el cambio climático. Estas incluyen:
#
# 1. **Fondos de Investigación Sospechosos y Grupos de Influencia**: Históricamente, las compañías de energía, como ExxonMobil y otras, han financiado grupos de investigación y think tanks que presentan dudas sobre el cambio climático. Estos grupos producen estudios, informes y comunicados de prensa que cuestionan la ciencia del calentamiento global.
#
# 2. **Presencia Mediática Estratégica**: Las compañías a menudo contratan a expertos y científicos para aparecer en medios de comunicación
# Extracted:
# <reasoning>
# Las compañías energéticas en Estados Unidos, especialmente aquellas que se beneficiarían de la explotación continua de combustibles fósiles, han empleado diversas estrategias a lo largo de los años para influir en la opinión pública sobre temas relacionados con el calentamiento global y el cambio climático. Estas incluyen:
#
# 1. **Fondos de Investigación Sospechosos y Grupos de Influencia**: Históricamente, las compañías de energía, como ExxonMobil y otras, han financiado grupos de investigación y think tanks que presentan dudas sobre el cambio climático. Estos grupos producen estudios, informes y comunicados de prensa que cuestionan la ciencia del calentamiento global.
#
# 2. **Presencia Mediática Estratégica**: Las compañías a menudo contratan a expertos y científicos para aparecer en medios de comunicación
# -------------------- Question:
# **¿Qué opinaba Ezer Weizman sobre el cumplimiento de la legislación internacional por parte de Israel?**
# Answer:
# ...
#
# En 2012, la campaña presidencial fue costosa, con los candidatos combinados de Barack Obama y Mitt Romney gastando más de $2 mil millones. Este gasto provocó preocupaciones significativas entre los observadores sobre el costo de las campañas políticas. Los medios de comunicación y las organizaciones de monitoreo de campañas señalaron el potencial impacto desproporcionado del dinero en la política y la influencia de las donaciones significativas en el proceso electoral.
#
# A medida que avanzaban los años desde 2012 hacia una nueva elección presidencial en 2016, se anticipaba que las elecciones podrían ser aún más costosas. Hay varias raz
# Extracted:
# <reasoning>
# Para abordar esta pregunta, es necesario considerar la información disponible sobre los costos de las elecciones presidenciales de los Estados Unidos en 2012 y las expectativas para 2016.
#
# En 2012, la campaña presidencial fue costosa, con los candidatos combinados de Barack Obama y Mitt Romney gastando más de $2 mil millones. Este gasto provocó preocupaciones significativas entre los observadores sobre el costo de las campañas políticas. Los medios de comunicación y las organizaciones de monitoreo de campañas señalaron el potencial impacto desproporcionado del dinero en la política y la influencia de las donaciones significativas en el proceso electoral.
#
# A medida que avanzaban los años desde 2012 hacia una nueva elección presidencial en 2016, se anticipaba que las elecciones podrían ser aún más costosas. Hay varias raz
# -------------------- Question:
# ¿Cómo describió Winston Churchill la Carta Magna en el texto?
# Answer:
# "La Carta Magna ... como dijo Winston Churchill, de un modo más extenso, la Carta de todo hombre que se respeta a sí mismo en cualquier momento y en cualquier país."
# Response:
# Para responder a esta pregunta, necesito conocer el texto específico o el contexto en el que Winston Churchill describió la Carta Magna. Churchill mencionó la Carta Magna en numerosas ocasiones a lo largo de su vida, a menudo usando metáforas o referencias históricas, y su percepción de la Carta Magna a veces cambió según las circunstancias históricas o sus propios puntos y objetivos.
#
# En un discurso notable en 1941 durante la Segunda Guerra Mundial, Churchill se refirió a la Carta Magna como un "papel envejecido y polvoriento... sin ninguna fuerza directa hoy en día", enfatizando que era más un símbolo de los principios de libertad y un precedente legal que un documento legislativo activo. Sin embargo, bajo otras circunstancias, puede haber presentado la Carta Magn
# Extracted:
# Para responder a esta pregunta, necesito conocer el texto específico o el contexto en el que Winston Churchill describió la Carta Magna. Churchill mencionó la Carta Magna en numerosas ocasiones a lo largo de su vida, a menudo usando metáforas o referencias históricas, y su percepción de la Carta Magna a veces cambió según las circunstancias históricas o sus propios puntos y objetivos.
#
# En un discurso notable en 1941 durante la Segunda Guerra Mundial, Churchill se refirió a la Carta Magna como un "papel envejecido y polvoriento... sin ninguna fuerza directa hoy en día", enfatizando que era más un símbolo de los principios de libertad y un precedente legal que un documento legislativo activo. Sin embargo, bajo otras circunstancias, puede haber presentado la Carta Magn
# -------------------- Question:
# **¿Qué contribución fundamental realizó a la lingüística moderna?**
# Answer:
# "Es autor de una aportación fundamental a la lingüística moderna, con la formulación teórica y el desarrollo del concepto de gramática transformacional, o generativa..."
# Response:
# <reasoning>
# Para abordar la pregunta de cuál fue la contribución fundamental a la lingüística moderna, podemos examinar el desarrollo histórico de la disciplina y las figuras clave involucradas en su evolución. La lingüística moderna comenzó a tomar forma como una ciencia rigurosa en el siglo XIX, pero la contribución más influyente puede atribuirse a Ferdinand de Saussure, un lingüista suizo que a menudo se considera el padre de la lingüística moderna.
#
# Saussure introdujo una perspectiva estructural para el estudio del lenguaje, que marcó un quiebre significativo respecto a las visiones anteriores. Su obra más notable, "Curso de Lingüística General", aunque fue compilada por sus estudiantes después de su muerte, presentó ideas revolucionarias que influenciaron profundamente el campo. Las principales contribuciones
# Extracted:
# <reasoning>
# Para abordar la pregunta de cuál fue la contribución fundamental a la lingüística moderna, podemos examinar el desarrollo histórico de la disciplina y las figuras clave involucradas en su evolución. La lingüística moderna comenzó a tomar forma como una ciencia rigurosa en el siglo XIX, pero la contribución más influyente puede atribuirse a Ferdinand de Saussure, un lingüista suizo que a menudo se considera el padre de la lingüística moderna.
#
# Saussure introdujo una perspectiva estructural para el estudio del lenguaje, que marcó un quiebre significativo respecto a las visiones anteriores. Su obra más notable, "Curso de Lingüística General", aunque fue compilada por sus estudiantes después de su muerte, presentó ideas revolucionarias que influenciaron profundamente el campo. Las principales contribuciones
# -------------------- Question:
# **¿Cómo son percibidos los intelectuales en el contexto de sus "enemigos"?**
# Answer:
# - Respuesta textual: "Los intelectuales de la antigua Unión Soviética defensores de los valores eran percibidos por Estados Unidos como disidentes respetables, mientras que no teníamos más que desprecio para los apparatchiks y los comisarios, intelectuales tecnocráticos y centrados en la política."
# Response:
# <reasoning>
# To understand how intellectuals are perceived in the context of their "enemies," it's important to consider the historical and social roles that intellectuals play and how this impacts their relationships with perceived adversaries.
#
# 1. **Role of Intellectuals**: Historically, intellectuals are individuals who use their expertise and knowledge to engage with and comment on social, political, and cultural issues. This often positions them as critics of established power structures, including governments, corporations, and religious institutions.
#
# 2. **Public Perception and Influence**: Because intellectuals often engage in public discourse, they can be seen as influential figures who shape public opinion and challenge the status quo. Their critiques can lead to social change or provoke resistance from those who feel threatened by such challenges.
#
# 3. **Potential for Conflict**: The critical stance of intellectuals can naturally lead to conflict with those in power or with ideologies that conflict with their viewpoints. This can result in being perceived as enemies by those who are criticized or who disagree with their ideas.
#
# 4.
# Extracted:
# <reasoning>
# To understand how intellectuals are perceived in the context of their "enemies," it's important to consider the historical and social roles that intellectuals play and how this impacts their relationships with perceived adversaries.
#
# 1. **Role of Intellectuals**: Historically, intellectuals are individuals who use their expertise and knowledge to engage with and comment on social, political, and cultural issues. This often positions them as critics of established power structures, including governments, corporations, and religious institutions.
#
# 2. **Public Perception and Influence**: Because intellectuals often engage in public discourse, they can be seen as influential figures who shape public opinion and challenge the status quo. Their critiques can lead to social change or provoke resistance from those who feel threatened by such challenges.
#
# 3. **Potential for Conflict**: The critical stance of intellectuals can naturally lead to conflict with those in power or with ideologies that conflict with their viewpoints. This can result in being perceived as enemies by those who are criticized or who disagree with their ideas.
#
# 4.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f0c0f43b49a3> in <cell line: 0>()
#      12     train_dataset = dataset,
#      13 )
# ---> 14 trainer.train()
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2169                 hf_hub_utils.enable_progress_bars()
#    2170         else:
# -> 2171             return inner_training_loop(
#    2172                 args=args,
#    2173                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/unsloth/models/llama.py in _fast_inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#
# /usr/local/lib/python3.11/dist-packages/unsloth/models/_utils.py in _unsloth_training_step(self, model, inputs, num_items_in_batch)
#
# /content/unsloth_compiled_cache/UnslothGRPOTrainer.py in _prepare_inputs(self, inputs)
#     900             all_prompts_text = gather_object(prompts_text)
#     901             if self.accelerator.is_main_process:
# --> 902                 outputs = self.llm.generate(all_prompts_text, sampling_params=self.sampling_params, use_tqdm=False, lora_request = self.model.load_lora('grpo_trainer_lora_model', load_tensors = True))
#     903                 completion_ids = [out.token_ids for completions in outputs for out in completions.outputs]
#     904             else:
#
# /usr/local/lib/python3.11/dist-packages/vllm/utils.py in inner(*args, **kwargs)
#    1055                     )
#    1056
# -> 1057             return fn(*args, **kwargs)
#    1058
#    1059         return inner  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/vllm/entrypoints/llm.py in generate(self, prompts, sampling_params, prompt_token_ids, use_tqdm, lora_request, prompt_adapter_request, guided_options_request, priority)
#     467             priority=priority)
#     468
# --> 469         outputs = self._run_engine(use_tqdm=use_tqdm)
#     470         return self.engine_class.validate_outputs(outputs, RequestOutput)
#     471
#
# /usr/local/lib/python3.11/dist-packages/vllm/entrypoints/llm.py in _run_engine(self, use_tqdm)
#    1395         total_out_toks = 0
#    1396         while self.llm_engine.has_unfinished_requests():
# -> 1397             step_outputs = self.llm_engine.step()
#    1398             for output in step_outputs:
#    1399                 if output.finished:
#
# /usr/local/lib/python3.11/dist-packages/vllm/engine/llm_engine.py in step(self)
#    1389                     virtual_engine]
#    1390
# -> 1391             outputs = self.model_executor.execute_model(
#    1392                 execute_model_req=execute_model_req)
#    1393
#
# /usr/local/lib/python3.11/dist-packages/vllm/executor/executor_base.py in execute_model(self, execute_model_req)
#     137         self, execute_model_req: ExecuteModelRequest
#     138     ) -> Optional[List[Union[SamplerOutput, PoolerOutput]]]:
# --> 139         output = self.collective_rpc("execute_model",
#     140                                      args=(execute_model_req, ))
#     141         return output[0]
#
# /usr/local/lib/python3.11/dist-packages/vllm/executor/uniproc_executor.py in collective_rpc(self, method, timeout, args, kwargs)
#      54         if kwargs is None:
#      55             kwargs = {}
# ---> 56         answer = run_method(self.driver_worker, method, args, kwargs)
#      57         return [answer]
#      58
#
# /usr/local/lib/python3.11/dist-packages/vllm/utils.py in run_method(obj, method, args, kwargs)
#    2194     else:
#    2195         func = partial(method, obj)  # type: ignore
# -> 2196     return func(*args, **kwargs)
#    2197
#    2198
#
# /usr/local/lib/python3.11/dist-packages/vllm/worker/worker_base.py in execute_model(self, execute_model_req)
#     418                     "model_execute_time", torch.tensor(0)).item()
#     419
# --> 420         output = self.model_runner.execute_model(
#     421             model_input=model_input,
#     422             kv_caches=self.kv_cache[worker_input.virtual_engine]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/vllm/worker/model_runner.py in execute_model(self, model_input, kv_caches, intermediate_tensors, num_steps, **kwargs)
#    1780
#    1781         # Sample the next token.
# -> 1782         output: SamplerOutput = self.model.sample(
#    1783             logits=logits,
#    1784             sampling_metadata=model_input.sampling_metadata,
#
# /usr/local/lib/python3.11/dist-packages/vllm/model_executor/models/llama.py in sample(self, logits, sampling_metadata)
#     561     def sample(self, logits: torch.Tensor,
#     562                sampling_metadata: SamplingMetadata) -> Optional[SamplerOutput]:
# --> 563         next_tokens = self.sampler(logits, sampling_metadata)
#     564         return next_tokens
#     565
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/vllm/model_executor/layers/sampler.py in forward(self, logits, sampling_metadata)
#     285
#     286         # Sample the next tokens.
# --> 287         maybe_deferred_sample_results, maybe_sampled_tokens_tensor = _sample(
#     288             probs,
#     289             logprobs,
#
# /usr/local/lib/python3.11/dist-packages/vllm/model_executor/layers/sampler.py in _sample(probs, logprobs, sampling_metadata, sampling_tensors, include_gpu_probs_tensor, modify_greedy_probs)
#     773         sampled_token_ids_tensor: A tensor of sampled token ids.
#     774     """
# --> 775     return _sample_with_torch(
#     776         probs,
#     777         logprobs,
#
# /usr/local/lib/python3.11/dist-packages/vllm/model_executor/layers/sampler.py in _sample_with_torch(probs, logprobs, sampling_metadata, sampling_tensors, include_gpu_probs_tensor, modify_greedy_probs)
#     742         # This also converts the sampler output to a Python object.
#     743         # Return Pythonized sampler result & sampled token ids
# --> 744         return get_pythonized_sample_results(
#     745             maybe_deferred_args), sampled_token_ids_tensor
#     746     else:
#
# /usr/local/lib/python3.11/dist-packages/vllm/model_executor/layers/sampler.py in get_pythonized_sample_results(sample_result_args)
#     614             sample_results = _greedy_sample(seq_groups, greedy_samples)
#     615         elif sampling_type in (SamplingType.RANDOM, SamplingType.RANDOM_SEED):
# --> 616             sample_results = _random_sample(seq_groups,
#     617                                             multinomial_samples[sampling_type])
#     618         sample_results_dict.update(zip(seq_group_id, sample_results))
#
# /usr/local/lib/python3.11/dist-packages/vllm/model_executor/layers/sampler.py in _random_sample(selected_seq_groups, random_samples)
#     483     """
#     484     # Find the maximum n value of the prompt phase requests.
# --> 485     random_samples = random_samples.cpu()
#     486     sample_idx = 0
#     487     results: SampleResultType = []
#
# KeyboardInterrupt:

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
#
# Now let's try the model we just trained! First, let's first try the model without any GRPO trained:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "user", "content" : "Which is bigger? 9.11 or 9.9?"},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    [text],
    sampling_params = sampling_params,
    lora_request = None,
)[0].outputs[0].text

output
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:16<00:00, 16.59s/it, est. speed input: 1.27 toks/s, output: 9.89 toks/s]
# '9.11 is bigger than 9.9. When comparing decimal numbers, you look at the digits from left to right. Both numbers have the same whole number part (9), so you compare the digits in the tenths place next. In 9.11, the tenths place is 1, and in 9.9, the tenths place is 9. Since 1 is less than 9, you might initially think 9.9 is larger, but you also need to consider the hundredths place in 9.11, which is 1. When you express 9.9 as 9.90 for comparison, you see that 9.11 is greater than 9.90. Therefore, 9.11 is bigger than 9.9.'

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_saved_lora")

# %% [markdown]
# Now we load the LoRA and test:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "system", "content" : SYSTEM_PROMPT},
    {"role" : "user", "content" : "Which is bigger? 9.11 or 9.9?"},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    text,
    sampling_params = sampling_params,
    lora_request = model.load_lora("grpo_saved_lora"),
)[0].outputs[0].text

output
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:27<00:00, 27.72s/it, est. speed input: 1.70 toks/s, output: 10.03 toks/s]
# '<reasoning>\nTo determine which number is bigger between 9.11 and 9.9, we should compare the two numbers digit by digit from left to right. \n\n1. First, compare the digits in the units place:\n   - Both numbers have a 9 in the units place.\n\n2. Next, compare the digits in the tenths place:\n   - The number 9.11 has a 1 in the tenths place.\n   - The number 9.9 has a 9 in the tenths place.\n\nSince 1 is less than 9, the number 9.11 is less than 9.9 based on the tenths place comparison.\n\n3. For thoroughness, consider the hundredths place:\n   - The number 9.11 has a 1 in the hundredths place.\n   - The number 9.9 can be written as 9.90, which has a 0 in the hundredths place.\n\nEven if we compare the hundredths place, 1 is greater than 0, but this is irrelevant since the comparison in the tenths place already determines that 9.11 is smaller than 9.9.\n\nTherefore, 9.9 is greater than 9.11.\n</reasoning>\n\n<answer>\n9.9 is bigger than 9.11.\n</answer>'

# %%
print(output)
# Out:
# <reasoning>
# To determine which number is bigger between 9.11 and 9.9, we should compare the two numbers digit by digit from left to right.
#
# 1. First, compare the digits in the units place:
#    - Both numbers have a 9 in the units place.
#
# 2. Next, compare the digits in the tenths place:
#    - The number 9.11 has a 1 in the tenths place.
#    - The number 9.9 has a 9 in the tenths place.
#
# Since 1 is less than 9, the number 9.11 is less than 9.9 based on the tenths place comparison.
#
# 3. For thoroughness, consider the hundredths place:
#    - The number 9.11 has a 1 in the hundredths place.
#    - The number 9.9 can be written as 9.90, which has a 0 in the hundredths place.
#
# Even if we compare the hundredths place, 1 is greater than 0, but this is irrelevant since the comparison in the tenths place already determines that 9.11 is smaller than 9.9.
#
# Therefore, 9.9 is greater than 9.11.
# </reasoning>
#
# <answer>
# 9.9 is bigger than 9.11.
# </answer>

# %% [markdown]
# Our reasoning model is much better - it's not always correct, since we only trained it for an hour or so - it'll be better if we extend the sequence length and train for longer!

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "",
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp or a UI based system like Jan or Open WebUI. You can install Jan [here](https://github.com/janhq/jan) and Open WebUI [here](https://github.com/open-webui/open-webui)
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Llama 3.2 Conversational notebook. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(1B_and_3B)-Conversational.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
